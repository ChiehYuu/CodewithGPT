# %% [markdown]
# # Research Playbook
# 本 Notebook 與儀表板共用函式庫，支援 vibe coding。

# %%
import pandas as pd
from src import io, cleaning, kpis, elasticity, econometrics, clv, attribution

# %% [markdown]
# ## 資料概述
# 使用 `io.load_excel` 讀取資料並 `profile_sheets` 進行摘要。

# %%
frames = io.load_excel('data/uploaded.xlsx')
profiles = io.profile_sheets(frames)
profiles

# %% [markdown]
# ## 假設產生模板
# 1. 價格敏感度
# 2. 稀缺性
# 3. 社會性證據
# 4. 黏著機制
# 5. 路徑依賴
